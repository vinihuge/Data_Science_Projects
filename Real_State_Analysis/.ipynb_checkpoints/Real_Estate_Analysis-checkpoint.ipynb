# %% [markdown]
# # Imports

# %%
import pandas as pd 
import numpy  as np

import matplotlib.pyplot as plt
import seaborn           as sns 

from sklearn.linear_model    import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics         import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing   import StandardScaler
from sklearn.ensemble        import RandomForestRegressor, GradientBoostingRegressor

# %% [markdown]
# # Loading Data

# %%
real_df = pd.read_csv('kc_house_data.csv')
real_df['date'] = pd.to_datetime(real_df['date'])
real_df.shape
# Out:
# (21613, 21)

# %%
real_df.head().T
# Out:
#                                  0                    1                    2  \
# id                      7129300520           6414100192           5631500400
# date           2014-10-13 00:00:00  2014-12-09 00:00:00  2015-02-25 00:00:00
# price                       221900               538000               180000
# bedrooms                         3                    3                    2
# bathrooms                        1                 2.25                    1
# sqft_living                   1180                 2570                  770
# sqft_lot                      5650                 7242                10000
# floors                           1                    2                    1
# waterfront                       0                    0                    0
# view                             0                    0                    0
# condition                        3                    3                    3
# grade                            7                    7                    6
# sqft_above                    1180                 2170                  770
# sqft_basement                    0                  400                    0
# yr_built                      1955                 1951                 1933
# yr_renovated                     0                 1991                    0
# zipcode                      98178                98125                98028
# lat                        47.5112               47.721              47.7379
# long                      -122.257             -122.319             -122.233
# sqft_living15                 1340                 1690                 2720
# sqft_lot15                    5650                 7639                 8062
#
#                                  3                    4
# id                      2487200875           1954400510
# date           2014-12-09 00:00:00  2015-02-18 00:00:00
# price                       604000               510000
# bedrooms                         4                    3
# bathrooms                        3                    2
# sqft_living                   1960                 1680
# sqft_lot                      5000                 8080
# floors                           1                    1
# waterfront                       0                    0
# view                             0                    0
# condition                        5                    3
# grade                            7                    8
# sqft_above                    1050                 1680
# sqft_basement                  910                    0
# yr_built                      1965                 1987
# yr_renovated                     0                    0
# zipcode                      98136                98074
# lat                        47.5208              47.6168
# long                      -122.393             -122.045
# sqft_living15                 1360                 1800
# sqft_lot15                    5000                 7503

# %%
real_df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
real_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # EDA

# %%
# Correlations between features and target
sns.set(rc={'figure.figsize':(15,8)})
corr = real_df.iloc[:,1:].corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
# Does the number of bedrooms affects the price of a house?
sns.boxplot(x='bedrooms', y='price', data=real_df)
plt.xlabel('Bedrooms', fontsize=20)
plt.ylabel('House Prices', fontsize=20)
plt.show()

# %%
# Number of bedrooms X Median price 
bedxprice = real_df[['bedrooms','price']].groupby('bedrooms').median().iloc[:-1,:]
plt.plot(bedxprice.index, bedxprice['price'])
plt.xticks([*range(1,12)])
plt.xlabel('Number of Bedrooms', fontsize=20)
plt.ylabel('House Prices', fontsize=20)
plt.show()

# %%
# Number of Houses Saled based on number of bedrooms
bedXsales = real_df[['bedrooms','price']].groupby('bedrooms').count().iloc[:-1,:]
bedXsales.plot.bar()
plt.xticks([*range(1,12)], rotation=0, fontsize=12)
plt.xlabel('Number of Bedrooms', fontsize=20)
plt.ylabel('Sales', fontsize=20)
plt.show()

# %%
# Influence of locality in the price
latxlong = real_df[['lat','long','price','waterfront']]
sns.scatterplot(x='lat',y='long',data=latxlong, size='price', hue='price')
plt.xlabel('Latitude', fontsize=20)
plt.ylabel('Longitude', fontsize=20)
plt.show()

# %%
# Dynamic of number of house sales and price of house during the year
datexcount = real_df[['date', 'price']].rename(columns={'price':'Sales', 'date':'Months'}).set_index('Months')
datexcount = datexcount.groupby(datexcount.index.month).count()

datexprice = real_df[['date', 'price']].rename(columns={'price':'Median Price', 'date':'Months'}).set_index('Months')
datexprice = datexprice.groupby(datexprice.index.month).median()

df_full = datexcount.join(datexprice)
df_full.plot(secondary_y=['Sales'])

plt.xticks(fontsize=15)
plt.yticks(fontsize=12, color='blue')
plt.xlabel('Months',fontsize=20) 
plt.show()

# %%
# Newest houses are more expensive?
yearXprice = real_df[['yr_built', 'price']].groupby('yr_built').median()
plt.scatter(real_df['yr_built'], real_df['price'], label='Distributions of House Prices along the Years')
plt.plot(yearXprice.index, yearXprice['price'], color='red', label='Median House Prices along the Years')
plt.ylabel('Prices', fontsize=20)
plt.xlabel('Years', fontsize=20)
plt.legend()
plt.show()

# %%
# Correlation between Square Footage Living and House Price 
livingXprice = real_df[['sqft_living', 'price']]
livingXprice = livingXprice.groupby(pd.cut(livingXprice["sqft_living"], np.arange(0, max(livingXprice['sqft_living']), 250))).mean()
sns.lineplot('sqft_living', 'price', data=livingXprice)
plt.ylabel('House Prices', fontsize=20)
plt.xlabel('Square Footage Living', fontsize=20)
plt.show()

# %% [markdown]
# # Data Preparation

# %%
# Split data
X = real_df.drop(['date', 'price','id'], axis=1)
y = real_df['price']

# Create training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %% [markdown]
# # Model Training - Linear Models

# %%
# Linear Regression
linreg = LinearRegression()
linreg.fit(X_train,y_train)

# Lasso Regression
lasso = Lasso(alpha=0.8, normalize=True)
lasso.fit(X_train,y_train)

# Ridge Regression
ridge = Ridge(alpha=0.8, normalize=True)
ridge.fit(X_train,y_train)

# ElasticNet Regression
l1_space = np.linspace(0, 1, 30)
param_grid = {'l1_ratio': l1_space}
elastic_net = ElasticNet()
elasticCV = GridSearchCV(elastic_net, param_grid, cv=5)
elasticCV.fit(X_train, y_train)
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318992804086778.5, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326120577730529.44, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 332968818676328.9, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 334417187188707.6, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340549345457221.0, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318347785433100.25, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 325515688468277.9, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 332352107333770.0, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333803871281755.0, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 339918465629996.7, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317672130785170.4, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324882018692882.0, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 331706184861162.6, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333161468558497.1, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 339257811339579.44, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316963566442988.3, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324217421341589.25, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 331028882658410.5, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 332487814823225.1, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 338565179505684.7, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316219578134487.7, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323519524717000.5, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 330317806361503.4, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 331780519904018.75, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 337838138368155.44, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315437385733065.44, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 322785701243244.4, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 329570304591859.94, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 331036936263833.94, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 337073995908375.56, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314613901008699.3, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 322013030599915.06, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 328783432105706.56, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 330254121967042.4, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 336269762621540.7, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313745683043585.7, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321198255942575.5, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327953906061598.4, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 329428796705321.3, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335422107347460.75, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312828884062136.2, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320337731543755.6, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327078053752134.3, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 328557289210197.8, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 334527304492658.7, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 311859184314652.56, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319427359676080.4, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326151749638495.44, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327635473865536.9, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 333581170465252.8, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 310831713131177.2, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318462513850767.2, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 325170338823946.06, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326658693621187.6, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 332578986434896.56, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 309740952280039.44, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317437944520984.0, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324128543107322.75, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 325621665301639.7, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 331515403526574.3, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308580616354929.2, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316347661916307.6, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323020344325867.2, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324518361952861.4, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 330384325112545.75, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 307343502846206.8, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315184788541571.7, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321838837580781.3, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323341864728721.7, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 329178758729371.7, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 306021301433932.4, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 313941370649432.1, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320576043737688.1, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 322084173577522.75, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327890626914873.0, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304604347211853.3, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312608132974283.1, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319222665606709.5, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320735960944158.56, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 326510521216497.56, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 303081294819298.0, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 311174152941611.06, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317767764178607.44, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319286244588120.06, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 325027375509987.6, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 301438677634036.6, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 309626417119240.7, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316198317912742.6, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317721942098130.4, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323428021222632.5, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 299660294000810.8, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 307949199328934.3, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314498604814736.25, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 316027246212609.3, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321696563519384.25, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 297726322313707.4, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 306123157424186.8, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312649304743316.94, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314182717398848.4, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319813474663727.6, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 295611990060650.0, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304123964474309.44, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 310626138241781.4, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312163908401024.06, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 317754218544940.0, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 293285466102368.7, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 301920124610423.06, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 308397692715010.8, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 309939168960860.75, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315487052620021.06, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 290704305082749.25, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 299469261631949.5, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 305921724102780.25, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 307465914373453.4, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 312969285749890.06, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287808961890786.3, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 296711304358423.0, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 303138355303602.0, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 304683771336199.0, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 310140391223704.56, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 284509743259547.0, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 293554698622846.3, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 299956286463493.5, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 301500702848762.1, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 306908035439334.4, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 280657020056549.25, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 289844792788425.25, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 296221093542641.3, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 297761171003413.5, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 303115946642238.4, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 275960563395576.28, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 285277960952764.6, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 291628819304182.5, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 293159566172695.3, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 298456337621121.4, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 269708692693561.9, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 279102069950168.78, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 285423012731465.2, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 286937744502838.2, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 292163112990890.3, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 259218357240093.5, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 268499567801577.25, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 274743015282505.72, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276247153592837.44, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 281344329659723.75, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 206279044455652.6, tolerance: 152839817805.31192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212161630691125.38, tolerance: 155913248159.0138
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217422416799109.84, tolerance: 158351834782.4061
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 218762524204112.66, tolerance: 159461852868.38077
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 222643194670254.44, tolerance: 164048281742.19482
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 269590833634134.84, tolerance: 197654197140.59027
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'l1_ratio': array([0.        , 0.03448276, 0.06896552, 0.10344828, 0.13793103,
#        0.17241379, 0.20689655, 0.24137931, 0.27586207, 0.31034483,
#        0.34482759, 0.37931034, 0.4137931 , 0.44827586, 0.48275862,
#        0.51724138, 0.55172414, 0.5862069 , 0.62068966, 0.65517241,
#        0.68965517, 0.72413793, 0.75862069, 0.79310345, 0.82758621,
#        0.86206897, 0.89655172, 0.93103448, 0.96551724, 1.        ])})

# %%
# lasso coefficients
lasso_coef = lasso.coef_
print('lasso coefficients:', lasso_coef)

# Plot coefficients
sns.set(rc={'figure.figsize':(15,5)})
plt.plot(range(len(X_train.columns)), lasso_coef)
plt.xticks(range(len(X_train.columns)), X_train.columns.values, rotation=60)
plt.xlabel('Features', fontsize=20)
plt.ylabel('Importance',fontsize=20)
plt.xticks(rotation = 90, fontsize=15)
plt.title('Lasso Regression',fontsize=20)
plt.margins(0.02)
plt.show()
# Out:
# lasso coefficients: [-3.40219448e+04  4.00854745e+04  1.51785686e+02  9.03468698e-02
#   5.03630711e+03  5.43222798e+05  5.50620496e+04  2.30100634e+04
#   9.49592674e+04  3.23081195e+01  0.00000000e+00 -2.58759586e+03
#   2.18194535e+01 -5.51052871e+02  5.94488699e+05 -1.95314584e+05
#   1.60571053e+01 -3.17608294e-01]

# %% [markdown]
# # Performance Metrics - Linear Models

# %%
# Absolute Error and Absolute error percentual (ae_aep)
def ae_aep(data):
    data['abs_error'] = round(np.abs(data['price'] - data['predict']), 2)
    data['abs_error_perc'] = round(np.abs(data['price'] - data['predict']) / data['price'] *100, 2)
    
    return data

# Mean Absolute Error (MAE)
def mae(data):
    mae = np.sum(data['abs_error'])/len(data['abs_error'])
    
    return round(mae, 2)

# Mean Absoulute Percentual Error (MAPE)
def mape(data):
    mape = np.mean(data['abs_error_perc'])
    
    return round(mape, 2)

# %%
#                                               TEST METRICS
# Predict
pred_linreg = linreg.predict(X_test)
pred_lasso  = lasso.predict(X_test)
pred_ridge  = ridge.predict(X_test)
pred_elast  = elasticCV.predict(X_test)

# Df for metrics 
df_linreg = pd.DataFrame({'price': y_test, 'predict': pred_linreg})
df_lasso  = pd.DataFrame({'price': y_test, 'predict': pred_lasso})
df_ridge  = pd.DataFrame({'price': y_test, 'predict': pred_ridge})
df_elastic= pd.DataFrame({'price': y_test, 'predict': pred_elast})
ae_aep(df_linreg)
ae_aep(df_lasso)
ae_aep(df_ridge)
ae_aep(df_elastic)


print('LinReg MAE: ', mae(df_linreg),
     '  Lasso MAE: ',  mae(df_lasso),
     '  Ridge MAE: ',  mae(df_ridge),
     '  Elastic MAE: ',  mae(df_elastic)
     )

print('LinReg MAPE:', mape(df_linreg),
'      Lasso MAPE:',  mape(df_lasso),
'      Ridge MAPE:',  mape(df_ridge),
'      Elastic MAPE:',  mape(df_elastic)
     )

print(  'LinReg R^2: ', round(linreg.score(X_test, y_test), 2),
 '       Lasso R^2: ',  round(lasso.score(X_test, y_test), 2),
'        Ridge R^2: ',  round(ridge.score(X_test, y_test), 2),
 '       Elastic R^2: ',  round(elasticCV.score(X_test, y_test), 2)
     )

print('LinReg RMSE:', round(np.sqrt(mean_squared_error(y_test, pred_linreg)), 2),
    '  Lasso RMSE:',  round(np.sqrt(mean_squared_error(y_test, pred_lasso)), 2),
    '  Ridge RMSE:',  round(np.sqrt(mean_squared_error(y_test, pred_ridge)), 2),
    '  Elastic RMSE:',  round(np.sqrt(mean_squared_error(y_test, pred_elast)), 2)
     )
print()
print("Tuned ElasticNet l1 ratio: {}".format(elasticCV.best_params_))
# Out:
# LinReg MAE:  127486.8   Lasso MAE:  127452.64   Ridge MAE:  130783.94   Elastic MAE:  127486.31
# LinReg MAPE: 25.3       Lasso MAPE: 25.29       Ridge MAPE: 25.21       Elastic MAPE: 25.3
# LinReg R^2:  0.7        Lasso R^2:  0.7         Ridge R^2:  0.64        Elastic R^2:  0.7
# LinReg RMSE: 208296.73   Lasso RMSE: 208323.26   Ridge RMSE: 228287.15   Elastic RMSE: 208297.9
#
# Tuned ElasticNet l1 ratio: {'l1_ratio': 1.0}

# %% [markdown]
# # Model Training - Random Forest

# %%
# Hyperparameters to search
param_grid = {'max_depth': [8,10, 15], 'max_features': [8,10, 15], 'random_state': [42]}

# Find the best hyperparameters
rfr = RandomForestRegressor(n_estimators=200)
clf = GridSearchCV(rfr, param_grid, cv=5)
clf.fit(X_train, y_train)

print("Tuned Random Forest Regression Parameters: {}".format(clf.best_params_)) 
print("Best score is {}".format(clf.best_score_))
# Out:
# Tuned Random Forest Regression Parameters: {'max_depth': 15, 'max_features': 8, 'random_state': 42}
# Best score is 0.878851714987341

# %% [markdown]
# # Performance Metrics - Random Forest

# %%
# Predict
pred_randfor = clf.predict(X_test)

# Df for metrics
df_randfor = pd.DataFrame({'price': y_test, 'predict': pred_randfor})
ae_aep(df_randfor)

print('Random Forest MAE: ', mae(df_randfor))
print('Random Forest MAPE:', mape(df_randfor))
print('Random Forest R^2: ', round(clf.score(X_test, y_test), 2))
print('Random Forest RMSE:', round(np.sqrt(mean_squared_error(y_test, pred_randfor)), 2))
# Out:
# Random Forest MAE:  73990.6
# Random Forest MAPE: 13.61
# Random Forest R^2:  0.86
# Random Forest RMSE: 144552.95

# %%
# Get feature importances 
rfr = RandomForestRegressor(n_estimators=200, max_depth= 15, max_features= 8, random_state = 42)
rfr.fit(X_train, y_train)
importances = rfr.feature_importances_

sorted_index = np.argsort(importances)[::-1]
x = range(len(importances))


labels = np.array(X_test.columns)[sorted_index]
plt.bar(x, importances[sorted_index], tick_label=labels)
plt.xlabel('Features', fontsize=20)
plt.ylabel('Importance', fontsize=20)
plt.xticks(rotation=90, fontsize=15)
plt.show()

# %% [markdown]
# # Model Training - Gradient Boosting

# %%
# GradientBoost model 
gbr = GradientBoostingRegressor(max_features=8,
                                learning_rate=0.01,
                                n_estimators=200,
                                subsample=0.6,
                                random_state=42)
gbr.fit(X_train, y_train)

print('Gradient Boosting R2 - Train:', gbr.score(X_train, y_train))
print('Gradient Boosting R2 - Test:',  gbr.score(X_test, y_test))
# Out:
# Gradient Boosting R2 - Train: 0.7582691106140398
# Gradient Boosting R2 - Test: 0.7267492135561464

# %% [markdown]
# # Performance Metrics - Gradient Boosting

# %%
# Predict
pred_gradboost = clf.predict(X_test)

# Df for metrics
df_gradboost = pd.DataFrame({'price': y_test, 'predict': pred_gradboost})
ae_aep(df_gradboost)

print('Random Forest MAE: ', mae(df_gradboost))
print('Random Forest MAPE:', mape(df_gradboost))
print('Random Forest R^2: ', round(gbr.score(X_test, y_test), 2))
print('Random Forest RMSE:', round(np.sqrt(mean_squared_error(y_test, pred_gradboost)), 2))
# Out:
# Random Forest MAE:  73990.6
# Random Forest MAPE: 13.61
# Random Forest R^2:  0.73
# Random Forest RMSE: 144552.95

# %%
# Extract feature importances 
feature_importances = gbr.feature_importances_
sorted_index = np.argsort(feature_importances)[::-1]
x = range(len(feature_importances))
labels = np.array(X_test.columns)[sorted_index]
plt.bar(x, feature_importances[sorted_index], tick_label=labels)
plt.xticks(rotation=90)
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,8)})
df_gradboost['bedrooms'], df_gradboost['sqft_living'] = X_test['bedrooms'], X_test['sqft_living']
plt.scatter(df_gradboost['predict'], df_gradboost['price'])
plt.xlabel('Predicted Price', fontsize=20)
plt.ylabel('Target Price', fontsize=20)
plt.show()
